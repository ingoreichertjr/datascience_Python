# %% [markdown]
# # Sistema de Recomendação de Músicas em Tempo Real
#
# ## Ferramentas utilizadas:
#
# - Api Spotify
# - Machine Leraning
# - PySpark
# - Spark Streaming
# - Apache Kafka

# %% [markdown]
# ## Arquivo Consumer

# %%
# Versão da linguagem Python
from platform import python_version
print(python_version())
# Out:
# 3.9.13

# %%
# Imports
import os
import time
import random
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.ml.feature import Normalizer, StandardScaler

# %%
# Endereço do servidor kafka
SERVER = 'localhost:9092'

# %%
# Nome do tópico
TOPIC = 'dsaminiprojeto7'

# %%
# Buscando os conectores (através de uma tupla) na minha pasta jars
spark_jars =  ("{},{},{},{},{}".format(os.getcwd() + "/jars/spark-sql-kafka-0-10_2.12-3.2.1.jar",  
                                       os.getcwd() + "/jars/kafka-clients-2.1.1.jar", 
                                       os.getcwd() + "/jars/spark-streaming-kafka-0-10-assembly_2.12-3.3.2.jar", 
                                       os.getcwd() + "/jars/commons-pool2-2.8.0.jar",  
                                       os.getcwd() + "/jars/spark-token-provider-kafka-0-10_2.12-3.1.2.jar"))

# %%
# Inicializa sessão Spark
spark = SparkSession \
        .builder \
        .config("spark.jars", spark_jars) \
        .appName("Projeto-Spotify") \
        .getOrCreate()

# %%
spark.sparkContext.setLogLevel("ERROR")

# %%
# Usamos o Spark Streaming para leitura do streaming de dados do Kafka e salvamos em um dataframe
df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", SERVER) \
        .option("subscribe", TOPIC) \
        .option("startingOffsets", "latest") \
        .load()

# %%
# Só quero que apareça mensagens de erro
df1 = df.selectExpr("CAST(value AS STRING)", "timestamp")

# %%
# Usamos o Spark Straming para leitura do streaming de dados do kafka e salvamos em um dataframe
df = spark \
        .readStream \
        .format('kafka') \
        .option('kafka.bootstrap.servers', SERVER) \
        .option('subscribe', TOPIC) \
        .option('startingOffsets', 'latset') \
        .load()

# %%
# Para aparecer apenas mensagens de erro
spark.sparkContext.setLogLevel("ERROR")

# %%
# Usamos o Spark Streaming para leitura do streaming de dados do Kafka e salvamos em um dataframe
df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", SERVER) \
        .option("subscribe", TOPIC) \
        .option("startingOffsets", "latest") \
        .load()

# %%
# Selecionamos a coluna timestamp como string e salvamos em um novo dataframe
df1 = df.selectExpr('CAST(value AS STRING)', 'timestamp')

# %%
# Definimos o schema com o nome de cada coluna e o tipo de dado
def_schema = "order_id INT, id STRING, name STRING, popularity INT, duration_ms DOUBLE, " \
             + "artists STRING, id_artists STRING, release_date STRING, " \
             + "danceability DOUBLE,energy DOUBLE, key INT, loudness DOUBLE, " \
             + "mode INT,speechiness DOUBLE," \
             + "acousticness DOUBLE, instrumentalness DOUBLE, liveness DOUBLE, " \
             + "valence DOUBLE, tempo DOUBLE, time_signature DOUBLE"

# %%
# Selecionamos o streaming de dados de acordo com o schema e salvamos um novo dataframe
df2 = df1.select(from_csv(col('value'), def_schema).alias('song'), 'timestamp')

# %%
# Criamos uma view (tabela temporária) na memória do Spark e visualizamos o schema
# Com o formato de tabela fica muito mais fácil de manipular os dados
df3 = df2.select('song.*', 'timestamp')
df3.createOrReplaceTempView('df3_View');
df3.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- duration_ms: double (nullable = true)
#  |-- artists: string (nullable = true)
#  |-- id_artists: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- loudness: double (nullable = true)
#  |-- mode: integer (nullable = true)
#  |-- speechiness: double (nullable = true)
#  |-- acousticness: double (nullable = true)
#  |-- instrumentalness: double (nullable = true)
#  |-- liveness: double (nullable = true)
#  |-- valence: double (nullable = true)
#  |-- tempo: double (nullable = true)
#  |-- time_signature: double (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
# Como os dados já estão estuturados posso aplicar SQL, através do spark,sql
# Selecionamos os dados com as músicas do stream
musicas_stream = spark.sql('SELECT * FROM df3_View')

# %%
# Não podemos visualizar ainda, pois temos que gerar o stram do Spark Streaming
# musicas_stream.show()

# %%
# Criamos o stram de dados do Spark Streaming
musicas_stream_spark = musicas_stream \
        .writeStream \
        .trigger(processingTime = '5 seconds') \
        .outputMode("append") \
        .option("truncate", "false") \
        .format("memory") \
        .queryName("tabela_spark") \
        .start()

musicas_stream_spark.awaitTermination(1)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# /tmp/ipykernel_5556/272017480.py in <module>
#       1 # Criamos o stram de dados do Spark Streaming
# ----> 2 musicas_stream_spark = musicas_stream \
#       3         .writeStream \
#       4         .trigger(processingTime = '5 seconds') \
#       5         .outputMode("append") \
#
# ~/anaconda3/lib/python3.9/site-packages/pyspark/sql/streaming.py in start(self, path, format, outputMode, partitionBy, queryName, **options)
#    1387             self.queryName(queryName)
#    1388         if path is None:
# -> 1389             return self._sq(self._jwrite.start())
#    1390         else:
#    1391             return self._sq(self._jwrite.start(path))
#
# ~/anaconda3/lib/python3.9/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# ~/anaconda3/lib/python3.9/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     194                 # Hide where the exception came from that shows a non-Pythonic
#     195                 # JVM exception message.
# --> 196                 raise converted from None
#     197             else:
#     198                 raise
#
# IllegalArgumentException: Cannot start query with name tabela_spark as a query with that name is already active in this SparkSession

# %%
# Selecionamos as músicas da tabela de stram do Spark
spark_songs = spark.sql('SELECT * FROM tabela_spark')

# %%
# Visualizando o stream em tempo real com tabela do Spark
spark_songs.show(5)
# Out:
# +--------+--------------------+--------------------+----------+-----------+--------------------+----------+------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-----+--------------+--------------------+
# |order_id|                  id|                name|popularity|duration_ms|             artists|id_artists|release_date|danceability|energy| key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|tempo|time_signature|           timestamp|
# +--------+--------------------+--------------------+----------+-----------+--------------------+----------+------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-----+--------------+--------------------+
# |     285|5pOumPAUcd7bgJi47...|       Nobody's Ting|         4|   213676.0|                NDAI|2018-05-04|        0.75|       0.525|   2.0|null|     1.0|null|      0.388|         0.0|           0.099|   0.528|143.912|  4.0|          null|2023-03-30 18:02:...|
# |     286|4YY8nv8tzU7AKLyRx...|                 You|         4|   131152.0|         GylesBartle|2018-05-11|       0.607|       0.331|   0.0|null|     1.0|null|      0.268|       0.327|           0.363|   0.663| 72.083|  4.0|          null|2023-03-30 18:02:...|
# |     287|7fAJw7CNYOOMbYr3S...|           Amor Fati|         0|   214884.0|ChampagneSuperchi...|2018-05-10|       0.362|       0.841|   2.0|null|     0.0|null|      0.123|       0.118|           0.117|   0.689|118.334|  4.0|          null|2023-03-30 18:02:...|
# |     288|4SzpxKCWRcKNNce1J...|Georgie Wants a G...|         9|   183533.0|            Blackaby|2018-05-11|       0.711|       0.573|  11.0|null|     1.0|null|      0.819|      0.0556|           0.118|   0.823|113.054|  4.0|          null|2023-03-30 18:02:...|
# |     289|40Ub2OAfCIxJa7OaO...|           So Simple|         6|   216173.0|      LucyandtheRats|2018-05-07|       0.343|       0.881|   4.0|null|     1.0|null|    0.00628|     1.64E-4|          0.0887|   0.444|151.737|  4.0|          null|2023-03-30 18:02:...|
# +--------+--------------------+--------------------+----------+-----------+--------------------+----------+------------+------------+------+----+--------+----+-----------+------------+----------------+--------+-------+-----+--------------+--------------------+
# only showing top 5 rows

# %%
# Visualizando apenas algumas colunas
spark_songs.select('order_id', 'id', 'name', 'popularity', 'duration_ms', 'artists').show(5)
# Out:
# +--------+--------------------+--------------------+----------+-----------+--------------------+
# |order_id|                  id|                name|popularity|duration_ms|             artists|
# +--------+--------------------+--------------------+----------+-----------+--------------------+
# |     285|5pOumPAUcd7bgJi47...|       Nobody's Ting|         4|   213676.0|                NDAI|
# |     286|4YY8nv8tzU7AKLyRx...|                 You|         4|   131152.0|         GylesBartle|
# |     287|7fAJw7CNYOOMbYr3S...|           Amor Fati|         0|   214884.0|ChampagneSuperchi...|
# |     288|4SzpxKCWRcKNNce1J...|Georgie Wants a G...|         9|   183533.0|            Blackaby|
# |     289|40Ub2OAfCIxJa7OaO...|           So Simple|         6|   216173.0|      LucyandtheRats|
# +--------+--------------------+--------------------+----------+-----------+--------------------+
# only showing top 5 rows

# %%
# Contagem de músicas extraídas em tempo real (no outro jupyter notebook)
spark_songs.count()
# Out:
# 1104

# %% [markdown]
# Importante aqui esperar um intervalo de tempo na continuação do projeto para que o streaming de dados possa ser coletado,

# %% [markdown]
# #### Vamos agora trabalhar na extração de dados do Spotify.

# %%
# Instalação do pacote python para criar a conexão com o Spotify
# https://spotipy.readthedocs.io/en/2.22.1/
# !pip install -q spotipy

# %%
# Imports
import os
import ujson
import spotipy
import spotipy.util
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
# Colocando as chaves da API do Spotify
os.environ['SPOTIPY_CLIENT_ID'] = 'e7badbd497da423692af1d504a6bee62'
os.environ['SPOTIPY_CLIENT_SECRET'] = '7f0136b895fb4614b55c50f7e0ccd920'
os.environ['SPOTIPY_REDIRECT_URI'] = 'http://localhost:7777/callback'

# %%
# Escopo de extração das preferências do usuário
# https://developer.spotify.com/documentation/web-api/concepts/scopes
scope = 'user-library-read'

# %%
# Username no Spotify
username = 'ingoreichertjr@gmail.com'

# %%
# Criação do token de acesso
token = spotipy.util.prompt_for_user_token(username, scope)

# %%
# Cria o objeto de autenticação
spotipy_obj = spotipy.Spotify(auth = token)

# %%
# Extrai até 50 músicas da lista de favoritos do usuário
saved_tracks = spotipy_obj.current_user_saved_tracks(limit = 50)

# %%
# Número de músicas extraídas
n_tracks = saved_tracks['total']
print('total de Tracks: %d ' % n_tracks)
# Out:
# total de Tracks: 55

# %%
# Função para extrair os atributos da lista de músicas do usuário
def select_features(track_response):
    return {
        'id': str(track_response['track']['id']),
        'name': str(track_response['track']['name']),
        'artists': [artist['name'] for artist in track_response['track']['artists']],
        'popularity': track_response['track']['popularity']
    }

# %%
# Aplica a função
tracks = [select_features(track) for track in saved_tracks['items']]

# %%
# Extrai os atributos das músicas preferidas do usuário
while saved_tracks['next']:
    saved_tracks = spotipy_obj.next(saved_tracks)
    tracks.extend([select_features(track) for track in saved_tracks['items']])

# %%
# Criamos o dataframe do pandas
df_tracks = pd.DataFrame(tracks)
pd.set_option('display.max_rows', len(tracks))
df_tracks['artists'] = df_tracks['artists'].apply(lambda artists: artists[0])

# %%
df_tracks.head(10)
# Out:
#                        id                                   name      artists  \
# 0  4zgyHc0bK2ca1U9X2iajg3          A Força do Silêncio (Ao Vivo)  Pouca Vogal
# 1  3OtbktRUMTzYrGTrdKaJUn                   A Montanha (Ao Vivo)  Pouca Vogal
# 2  6RWbbxUbtbadvUtg4tz1ab             O Vôo do Besouro (Ao Vivo)  Pouca Vogal
# 3  5eMgoUmfSjCdiUaP0fNgDD                  Pouca Vogal (Ao Vivo)  Pouca Vogal
# 4  7rL1ExqyusHQJjXZ2ZSDxQ            O Amanhã Colorido (Ao Vivo)  Pouca Vogal
# 5  5E0sfiyI5PyHK3x54XuYyA               Ao Fim de Tudo (Ao Vivo)  Pouca Vogal
# 6  3bhBlHJKJklCeQQ2QRHZMR                 Tententender (Ao Vivo)  Pouca Vogal
# 7  21Y2IgF2u7IpXSjmOMYO90             Refrão de Bolero (Ao Vivo)  Pouca Vogal
# 8  4EYhfZnsQRHzQ3FUC425qO  Toda Forma De Poder + Banco (Ao Vivo)  Pouca Vogal
# 9  73jOMwbzFrXVjCAqnbShYx                       Pinhal (Ao Vivo)  Pouca Vogal
#
#    popularity
# 0          31
# 1          29
# 2          26
# 3          24
# 4          37
# 5          27
# 6          27
# 7          44
# 8          28
# 9          33

# %% [markdown]
# Nosso sistema de recomendação vai aprender a partir das características de áudio das músicas, por isso vamos extraí-los a seguir:

# %%
# Dicionário para os atributos de áudio
audio_features = {}

# %%
# Extrai os atributos de áudio
# O pŕoprio objeto do spotify já oferece isso a partir do método audio_features
for idd in df_tracks['id'].tolist():
    audio_features[idd] = spotipy_obj.audio_features(idd)[0]

# %%
audio_features
# Out:
# {'4zgyHc0bK2ca1U9X2iajg3': {'danceability': 0.55,
#   'energy': 0.618,
#   'key': 2,
#   'loudness': -7.509,
#   'mode': 0,
#   'speechiness': 0.0311,
#   'acousticness': 0.624,
#   'instrumentalness': 0,
#   'liveness': 0.737,
#   'valence': 0.684,
#   'tempo': 138.01,
#   'type': 'audio_features',
#   'id': '4zgyHc0bK2ca1U9X2iajg3',
#   'uri': 'spotify:track:4zgyHc0bK2ca1U9X2iajg3',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zgyHc0bK2ca1U9X2iajg3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zgyHc0bK2ca1U9X2iajg3',
#   'duration_ms': 267773,
#   'time_signature': 4},
#  '3OtbktRUMTzYrGTrdKaJUn': {'danceability': 0.556,
#   'energy': 0.366,
#   'key': 7,
#   'loudness': -12.399,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.882,
#   'instrumentalness': 0.00966,
#   'liveness': 0.726,
#   'valence': 0.46,
#   'tempo': 137.822,
#   'type': 'audio_features',
#   'id': '3OtbktRUMTzYrGTrdKaJUn',
#   'uri': 'spotify:track:3OtbktRUMTzYrGTrdKaJUn',
#   'track_href': 'https://api.spotify.com/v1/tracks/3OtbktRUMTzYrGTrdKaJUn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OtbktRUMTzYrGTrdKaJUn',
#   'duration_ms': 154587,
#   'time_signature': 3},
#  '6RWbbxUbtbadvUtg4tz1ab': {'danceability': 0.599,
#   'energy': 0.357,
#   'key': 4,
#   'loudness': -12.167,
#   'mode': 0,
#   'speechiness': 0.0306,
#   'acousticness': 0.823,
#   'instrumentalness': 5.03e-05,
#   'liveness': 0.969,
#   'valence': 0.224,
#   'tempo': 132.033,
#   'type': 'audio_features',
#   'id': '6RWbbxUbtbadvUtg4tz1ab',
#   'uri': 'spotify:track:6RWbbxUbtbadvUtg4tz1ab',
#   'track_href': 'https://api.spotify.com/v1/tracks/6RWbbxUbtbadvUtg4tz1ab',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6RWbbxUbtbadvUtg4tz1ab',
#   'duration_ms': 210107,
#   'time_signature': 4},
#  '5eMgoUmfSjCdiUaP0fNgDD': {'danceability': 0.381,
#   'energy': 0.633,
#   'key': 9,
#   'loudness': -8.023,
#   'mode': 1,
#   'speechiness': 0.0462,
#   'acousticness': 0.719,
#   'instrumentalness': 0.0312,
#   'liveness': 0.979,
#   'valence': 0.35,
#   'tempo': 103.239,
#   'type': 'audio_features',
#   'id': '5eMgoUmfSjCdiUaP0fNgDD',
#   'uri': 'spotify:track:5eMgoUmfSjCdiUaP0fNgDD',
#   'track_href': 'https://api.spotify.com/v1/tracks/5eMgoUmfSjCdiUaP0fNgDD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5eMgoUmfSjCdiUaP0fNgDD',
#   'duration_ms': 215907,
#   'time_signature': 4},
#  '7rL1ExqyusHQJjXZ2ZSDxQ': {'danceability': 0.505,
#   'energy': 0.609,
#   'key': 2,
#   'loudness': -7.791,
#   'mode': 1,
#   'speechiness': 0.0366,
#   'acousticness': 0.188,
#   'instrumentalness': 0,
#   'liveness': 0.983,
#   'valence': 0.572,
#   'tempo': 122.056,
#   'type': 'audio_features',
#   'id': '7rL1ExqyusHQJjXZ2ZSDxQ',
#   'uri': 'spotify:track:7rL1ExqyusHQJjXZ2ZSDxQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/7rL1ExqyusHQJjXZ2ZSDxQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7rL1ExqyusHQJjXZ2ZSDxQ',
#   'duration_ms': 212427,
#   'time_signature': 4},
#  '5E0sfiyI5PyHK3x54XuYyA': {'danceability': 0.527,
#   'energy': 0.477,
#   'key': 9,
#   'loudness': -9.33,
#   'mode': 1,
#   'speechiness': 0.0304,
#   'acousticness': 0.861,
#   'instrumentalness': 0.00156,
#   'liveness': 0.977,
#   'valence': 0.211,
#   'tempo': 75.058,
#   'type': 'audio_features',
#   'id': '5E0sfiyI5PyHK3x54XuYyA',
#   'uri': 'spotify:track:5E0sfiyI5PyHK3x54XuYyA',
#   'track_href': 'https://api.spotify.com/v1/tracks/5E0sfiyI5PyHK3x54XuYyA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5E0sfiyI5PyHK3x54XuYyA',
#   'duration_ms': 192520,
#   'time_signature': 4},
#  '3bhBlHJKJklCeQQ2QRHZMR': {'danceability': 0.507,
#   'energy': 0.419,
#   'key': 0,
#   'loudness': -8.337,
#   'mode': 1,
#   'speechiness': 0.0262,
#   'acousticness': 0.708,
#   'instrumentalness': 0.000178,
#   'liveness': 0.959,
#   'valence': 0.167,
#   'tempo': 108.001,
#   'type': 'audio_features',
#   'id': '3bhBlHJKJklCeQQ2QRHZMR',
#   'uri': 'spotify:track:3bhBlHJKJklCeQQ2QRHZMR',
#   'track_href': 'https://api.spotify.com/v1/tracks/3bhBlHJKJklCeQQ2QRHZMR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3bhBlHJKJklCeQQ2QRHZMR',
#   'duration_ms': 254880,
#   'time_signature': 4},
#  '21Y2IgF2u7IpXSjmOMYO90': {'danceability': 0.519,
#   'energy': 0.435,
#   'key': 11,
#   'loudness': -8.348,
#   'mode': 0,
#   'speechiness': 0.0354,
#   'acousticness': 0.724,
#   'instrumentalness': 8.81e-05,
#   'liveness': 0.746,
#   'valence': 0.311,
#   'tempo': 150.154,
#   'type': 'audio_features',
#   'id': '21Y2IgF2u7IpXSjmOMYO90',
#   'uri': 'spotify:track:21Y2IgF2u7IpXSjmOMYO90',
#   'track_href': 'https://api.spotify.com/v1/tracks/21Y2IgF2u7IpXSjmOMYO90',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21Y2IgF2u7IpXSjmOMYO90',
#   'duration_ms': 182147,
#   'time_signature': 4},
#  '4EYhfZnsQRHzQ3FUC425qO': {'danceability': 0.646,
#   'energy': 0.874,
#   'key': 4,
#   'loudness': -6.162,
#   'mode': 1,
#   'speechiness': 0.0429,
#   'acousticness': 0.0555,
#   'instrumentalness': 1.1e-06,
#   'liveness': 0.979,
#   'valence': 0.565,
#   'tempo': 102.082,
#   'type': 'audio_features',
#   'id': '4EYhfZnsQRHzQ3FUC425qO',
#   'uri': 'spotify:track:4EYhfZnsQRHzQ3FUC425qO',
#   'track_href': 'https://api.spotify.com/v1/tracks/4EYhfZnsQRHzQ3FUC425qO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4EYhfZnsQRHzQ3FUC425qO',
#   'duration_ms': 254787,
#   'time_signature': 4},
#  '73jOMwbzFrXVjCAqnbShYx': {'danceability': 0.552,
#   'energy': 0.512,
#   'key': 2,
#   'loudness': -7.691,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.572,
#   'instrumentalness': 1.05e-06,
#   'liveness': 0.968,
#   'valence': 0.37,
#   'tempo': 78.407,
#   'type': 'audio_features',
#   'id': '73jOMwbzFrXVjCAqnbShYx',
#   'uri': 'spotify:track:73jOMwbzFrXVjCAqnbShYx',
#   'track_href': 'https://api.spotify.com/v1/tracks/73jOMwbzFrXVjCAqnbShYx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/73jOMwbzFrXVjCAqnbShYx',
#   'duration_ms': 224213,
#   'time_signature': 4},
#  '65hmYCsNSrfedagYXtT1Fr': {'danceability': 0.614,
#   'energy': 0.638,
#   'key': 11,
#   'loudness': -5.63,
#   'mode': 1,
#   'speechiness': 0.0308,
#   'acousticness': 0.656,
#   'instrumentalness': 1.43e-06,
#   'liveness': 0.958,
#   'valence': 0.445,
#   'tempo': 134.016,
#   'type': 'audio_features',
#   'id': '65hmYCsNSrfedagYXtT1Fr',
#   'uri': 'spotify:track:65hmYCsNSrfedagYXtT1Fr',
#   'track_href': 'https://api.spotify.com/v1/tracks/65hmYCsNSrfedagYXtT1Fr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/65hmYCsNSrfedagYXtT1Fr',
#   'duration_ms': 206227,
#   'time_signature': 4},
#  '4aKELhBz6QQaMBRS6tkISL': {'danceability': 0.466,
#   'energy': 0.523,
#   'key': 4,
#   'loudness': -9.41,
#   'mode': 1,
#   'speechiness': 0.0299,
#   'acousticness': 0.847,
#   'instrumentalness': 3.34e-05,
#   'liveness': 0.972,
#   'valence': 0.465,
#   'tempo': 147.756,
#   'type': 'audio_features',
#   'id': '4aKELhBz6QQaMBRS6tkISL',
#   'uri': 'spotify:track:4aKELhBz6QQaMBRS6tkISL',
#   'track_href': 'https://api.spotify.com/v1/tracks/4aKELhBz6QQaMBRS6tkISL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4aKELhBz6QQaMBRS6tkISL',
#   'duration_ms': 303813,
#   'time_signature': 4},
#  '2bhQ1EE8mf7oUIPU6dqjOQ': {'danceability': 0.613,
#   'energy': 0.483,
#   'key': 0,
#   'loudness': -11.716,
#   'mode': 0,
#   'speechiness': 0.0307,
#   'acousticness': 0.792,
#   'instrumentalness': 1.41e-05,
#   'liveness': 0.977,
#   'valence': 0.599,
#   'tempo': 134.117,
#   'type': 'audio_features',
#   'id': '2bhQ1EE8mf7oUIPU6dqjOQ',
#   'uri': 'spotify:track:2bhQ1EE8mf7oUIPU6dqjOQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2bhQ1EE8mf7oUIPU6dqjOQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bhQ1EE8mf7oUIPU6dqjOQ',
#   'duration_ms': 289507,
#   'time_signature': 4},
#  '6ngWHCZjxjs9n9w3vVNeo6': {'danceability': 0.431,
#   'energy': 0.429,
#   'key': 9,
#   'loudness': -12.455,
#   'mode': 1,
#   'speechiness': 0.044,
#   'acousticness': 0.748,
#   'instrumentalness': 8.59e-05,
#   'liveness': 0.716,
#   'valence': 0.426,
#   'tempo': 84.254,
#   'type': 'audio_features',
#   'id': '6ngWHCZjxjs9n9w3vVNeo6',
#   'uri': 'spotify:track:6ngWHCZjxjs9n9w3vVNeo6',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ngWHCZjxjs9n9w3vVNeo6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ngWHCZjxjs9n9w3vVNeo6',
#   'duration_ms': 194253,
#   'time_signature': 4},
#  '5KoHQSqiOl0hjbq4b7LvCz': {'danceability': 0.658,
#   'energy': 0.668,
#   'key': 7,
#   'loudness': -8.086,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.658,
#   'instrumentalness': 0,
#   'liveness': 0.978,
#   'valence': 0.75,
#   'tempo': 102.056,
#   'type': 'audio_features',
#   'id': '5KoHQSqiOl0hjbq4b7LvCz',
#   'uri': 'spotify:track:5KoHQSqiOl0hjbq4b7LvCz',
#   'track_href': 'https://api.spotify.com/v1/tracks/5KoHQSqiOl0hjbq4b7LvCz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KoHQSqiOl0hjbq4b7LvCz',
#   'duration_ms': 237253,
#   'time_signature': 4},
#  '4FIOChYPpshE6qduMjxWx4': {'danceability': 0.664,
#   'energy': 0.537,
#   'key': 9,
#   'loudness': -9.229,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.736,
#   'instrumentalness': 0.000167,
#   'liveness': 0.773,
#   'valence': 0.543,
#   'tempo': 130.092,
#   'type': 'audio_features',
#   'id': '4FIOChYPpshE6qduMjxWx4',
#   'uri': 'spotify:track:4FIOChYPpshE6qduMjxWx4',
#   'track_href': 'https://api.spotify.com/v1/tracks/4FIOChYPpshE6qduMjxWx4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4FIOChYPpshE6qduMjxWx4',
#   'duration_ms': 214213,
#   'time_signature': 4},
#  '3Ymoa8ocZEEhjG1gSwu2hC': {'danceability': 0.506,
#   'energy': 0.534,
#   'key': 7,
#   'loudness': -7.7,
#   'mode': 1,
#   'speechiness': 0.0243,
#   'acousticness': 0.559,
#   'instrumentalness': 0,
#   'liveness': 0.878,
#   'valence': 0.494,
#   'tempo': 89.991,
#   'type': 'audio_features',
#   'id': '3Ymoa8ocZEEhjG1gSwu2hC',
#   'uri': 'spotify:track:3Ymoa8ocZEEhjG1gSwu2hC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Ymoa8ocZEEhjG1gSwu2hC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Ymoa8ocZEEhjG1gSwu2hC',
#   'duration_ms': 200080,
#   'time_signature': 4},
#  '7LcD5GZhdKoscFRGnE2iIG': {'danceability': 0.497,
#   'energy': 0.447,
#   'key': 7,
#   'loudness': -9.14,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.855,
#   'instrumentalness': 0,
#   'liveness': 0.702,
#   'valence': 0.5,
#   'tempo': 135.99,
#   'type': 'audio_features',
#   'id': '7LcD5GZhdKoscFRGnE2iIG',
#   'uri': 'spotify:track:7LcD5GZhdKoscFRGnE2iIG',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LcD5GZhdKoscFRGnE2iIG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LcD5GZhdKoscFRGnE2iIG',
#   'duration_ms': 216693,
#   'time_signature': 4},
#  '5nYyyjWuxDnPW9WqIhIzgM': {'danceability': 0.644,
#   'energy': 0.549,
#   'key': 7,
#   'loudness': -8.255,
#   'mode': 1,
#   'speechiness': 0.0377,
#   'acousticness': 0.654,
#   'instrumentalness': 0,
#   'liveness': 0.974,
#   'valence': 0.626,
#   'tempo': 124.017,
#   'type': 'audio_features',
#   'id': '5nYyyjWuxDnPW9WqIhIzgM',
#   'uri': 'spotify:track:5nYyyjWuxDnPW9WqIhIzgM',
#   'track_href': 'https://api.spotify.com/v1/tracks/5nYyyjWuxDnPW9WqIhIzgM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nYyyjWuxDnPW9WqIhIzgM',
#   'duration_ms': 286960,
#   'time_signature': 4},
#  '23CLwKTdIf4mb5dBIrkQn5': {'danceability': 0.571,
#   'energy': 0.474,
#   'key': 7,
#   'loudness': -10.31,
#   'mode': 1,
#   'speechiness': 0.0239,
#   'acousticness': 0.648,
#   'instrumentalness': 6.06e-05,
#   'liveness': 0.745,
#   'valence': 0.642,
#   'tempo': 104.108,
#   'type': 'audio_features',
#   'id': '23CLwKTdIf4mb5dBIrkQn5',
#   'uri': 'spotify:track:23CLwKTdIf4mb5dBIrkQn5',
#   'track_href': 'https://api.spotify.com/v1/tracks/23CLwKTdIf4mb5dBIrkQn5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23CLwKTdIf4mb5dBIrkQn5',
#   'duration_ms': 187813,
#   'time_signature': 4},
#  '3g5FrnRdbmDQyWNiDIprts': {'danceability': 0.512,
#   'energy': 0.391,
#   'key': 9,
#   'loudness': -10.4,
#   'mode': 1,
#   'speechiness': 0.0492,
#   'acousticness': 0.889,
#   'instrumentalness': 2.63e-06,
#   'liveness': 0.714,
#   'valence': 0.277,
#   'tempo': 138.094,
#   'type': 'audio_features',
#   'id': '3g5FrnRdbmDQyWNiDIprts',
#   'uri': 'spotify:track:3g5FrnRdbmDQyWNiDIprts',
#   'track_href': 'https://api.spotify.com/v1/tracks/3g5FrnRdbmDQyWNiDIprts',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3g5FrnRdbmDQyWNiDIprts',
#   'duration_ms': 233613,
#   'time_signature': 4},
#  '7Dwpdw55WA34G6IlAqbfK8': {'danceability': 0.368,
#   'energy': 0.766,
#   'key': 0,
#   'loudness': -6.331,
#   'mode': 1,
#   'speechiness': 0.0865,
#   'acousticness': 0.428,
#   'instrumentalness': 5.63e-06,
#   'liveness': 0.704,
#   'valence': 0.796,
#   'tempo': 181.743,
#   'type': 'audio_features',
#   'id': '7Dwpdw55WA34G6IlAqbfK8',
#   'uri': 'spotify:track:7Dwpdw55WA34G6IlAqbfK8',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Dwpdw55WA34G6IlAqbfK8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Dwpdw55WA34G6IlAqbfK8',
#   'duration_ms': 184640,
#   'time_signature': 4},
#  '3s9CdqskE6kq6yrinJYMyp': {'danceability': 0.478,
#   'energy': 0.806,
#   'key': 7,
#   'loudness': -6.66,
#   'mode': 1,
#   'speechiness': 0.0394,
#   'acousticness': 0.00738,
#   'instrumentalness': 0.000433,
#   'liveness': 0.29,
#   'valence': 0.213,
#   'tempo': 84.084,
#   'type': 'audio_features',
#   'id': '3s9CdqskE6kq6yrinJYMyp',
#   'uri': 'spotify:track:3s9CdqskE6kq6yrinJYMyp',
#   'track_href': 'https://api.spotify.com/v1/tracks/3s9CdqskE6kq6yrinJYMyp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3s9CdqskE6kq6yrinJYMyp',
#   'duration_ms': 334733,
#   'time_signature': 4},
#  '26npCYqeFedyMyuRgxXlPX': {'danceability': 0.488,
#   'energy': 0.413,
#   'key': 9,
#   'loudness': -9.982,
#   'mode': 1,
#   'speechiness': 0.0282,
#   'acousticness': 0.612,
#   'instrumentalness': 0.0121,
#   'liveness': 0.15,
#   'valence': 0.325,
#   'tempo': 141.452,
#   'type': 'audio_features',
#   'id': '26npCYqeFedyMyuRgxXlPX',
#   'uri': 'spotify:track:26npCYqeFedyMyuRgxXlPX',
#   'track_href': 'https://api.spotify.com/v1/tracks/26npCYqeFedyMyuRgxXlPX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/26npCYqeFedyMyuRgxXlPX',
#   'duration_ms': 214909,
#   'time_signature': 4},
#  '0UwhTFitxpBbWOSk6vA5dv': {'danceability': 0.383,
#   'energy': 0.492,
#   'key': 0,
#   'loudness': -7.327,
#   'mode': 1,
#   'speechiness': 0.028,
#   'acousticness': 0.637,
#   'instrumentalness': 2.62e-06,
#   'liveness': 0.191,
#   'valence': 0.254,
#   'tempo': 89.515,
#   'type': 'audio_features',
#   'id': '0UwhTFitxpBbWOSk6vA5dv',
#   'uri': 'spotify:track:0UwhTFitxpBbWOSk6vA5dv',
#   'track_href': 'https://api.spotify.com/v1/tracks/0UwhTFitxpBbWOSk6vA5dv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0UwhTFitxpBbWOSk6vA5dv',
#   'duration_ms': 224920,
#   'time_signature': 4},
#  '0icAGFHI6XbakLkrGiNLFW': {'danceability': 0.62,
#   'energy': 0.638,
#   'key': 2,
#   'loudness': -6.928,
#   'mode': 0,
#   'speechiness': 0.0283,
#   'acousticness': 0.503,
#   'instrumentalness': 0,
#   'liveness': 0.261,
#   'valence': 0.603,
#   'tempo': 76.022,
#   'type': 'audio_features',
#   'id': '0icAGFHI6XbakLkrGiNLFW',
#   'uri': 'spotify:track:0icAGFHI6XbakLkrGiNLFW',
#   'track_href': 'https://api.spotify.com/v1/tracks/0icAGFHI6XbakLkrGiNLFW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0icAGFHI6XbakLkrGiNLFW',
#   'duration_ms': 213880,
#   'time_signature': 4},
#  '6rs96E1pfzZgBdNQKqOjEy': {'danceability': 0.339,
#   'energy': 0.882,
#   'key': 9,
#   'loudness': -4.85,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.17,
#   'instrumentalness': 6.57e-05,
#   'liveness': 0.0985,
#   'valence': 0.679,
#   'tempo': 154.187,
#   'type': 'audio_features',
#   'id': '6rs96E1pfzZgBdNQKqOjEy',
#   'uri': 'spotify:track:6rs96E1pfzZgBdNQKqOjEy',
#   'track_href': 'https://api.spotify.com/v1/tracks/6rs96E1pfzZgBdNQKqOjEy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6rs96E1pfzZgBdNQKqOjEy',
#   'duration_ms': 239827,
#   'time_signature': 4},
#  '4xRl53e2WsFTJJva9c7DNk': {'danceability': 0.357,
#   'energy': 0.706,
#   'key': 5,
#   'loudness': -5.879,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.345,
#   'instrumentalness': 0.0021,
#   'liveness': 0.307,
#   'valence': 0.389,
#   'tempo': 154.651,
#   'type': 'audio_features',
#   'id': '4xRl53e2WsFTJJva9c7DNk',
#   'uri': 'spotify:track:4xRl53e2WsFTJJva9c7DNk',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xRl53e2WsFTJJva9c7DNk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xRl53e2WsFTJJva9c7DNk',
#   'duration_ms': 258267,
#   'time_signature': 4},
#  '6HhXiy5XZ81Pyv3yCZMtj1': {'danceability': 0.3,
#   'energy': 0.7,
#   'key': 2,
#   'loudness': -6.567,
#   'mode': 1,
#   'speechiness': 0.036,
#   'acousticness': 0.53,
#   'instrumentalness': 0,
#   'liveness': 0.186,
#   'valence': 0.398,
#   'tempo': 165.642,
#   'type': 'audio_features',
#   'id': '6HhXiy5XZ81Pyv3yCZMtj1',
#   'uri': 'spotify:track:6HhXiy5XZ81Pyv3yCZMtj1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HhXiy5XZ81Pyv3yCZMtj1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HhXiy5XZ81Pyv3yCZMtj1',
#   'duration_ms': 246493,
#   'time_signature': 4},
#  '5B4qjbdMD3N2QEK1VQzIwN': {'danceability': 0.598,
#   'energy': 0.531,
#   'key': 4,
#   'loudness': -8.276,
#   'mode': 1,
#   'speechiness': 0.0317,
#   'acousticness': 0.753,
#   'instrumentalness': 1.7e-05,
#   'liveness': 0.0793,
#   'valence': 0.521,
#   'tempo': 82.074,
#   'type': 'audio_features',
#   'id': '5B4qjbdMD3N2QEK1VQzIwN',
#   'uri': 'spotify:track:5B4qjbdMD3N2QEK1VQzIwN',
#   'track_href': 'https://api.spotify.com/v1/tracks/5B4qjbdMD3N2QEK1VQzIwN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5B4qjbdMD3N2QEK1VQzIwN',
#   'duration_ms': 217886,
#   'time_signature': 4},
#  '5qm2hvZI2uImp2JNhqnIhs': {'danceability': 0.467,
#   'energy': 0.971,
#   'key': 2,
#   'loudness': -4.787,
#   'mode': 1,
#   'speechiness': 0.0913,
#   'acousticness': 0.00496,
#   'instrumentalness': 0.435,
#   'liveness': 0.548,
#   'valence': 0.524,
#   'tempo': 158.052,
#   'type': 'audio_features',
#   'id': '5qm2hvZI2uImp2JNhqnIhs',
#   'uri': 'spotify:track:5qm2hvZI2uImp2JNhqnIhs',
#   'track_href': 'https://api.spotify.com/v1/tracks/5qm2hvZI2uImp2JNhqnIhs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qm2hvZI2uImp2JNhqnIhs',
#   'duration_ms': 215053,
#   'time_signature': 4},
#  '2wjBr0Y3vWqVikEs3LsJ9J': {'danceability': 0.496,
#   'energy': 0.973,
#   'key': 2,
#   'loudness': -4.943,
#   'mode': 1,
#   'speechiness': 0.14,
#   'acousticness': 0.00138,
#   'instrumentalness': 0.0853,
#   'liveness': 0.981,
#   'valence': 0.59,
#   'tempo': 129.997,
#   'type': 'audio_features',
#   'id': '2wjBr0Y3vWqVikEs3LsJ9J',
#   'uri': 'spotify:track:2wjBr0Y3vWqVikEs3LsJ9J',
#   'track_href': 'https://api.spotify.com/v1/tracks/2wjBr0Y3vWqVikEs3LsJ9J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wjBr0Y3vWqVikEs3LsJ9J',
#   'duration_ms': 294293,
#   'time_signature': 4},
#  '0MsMDREQOOfu9rJz8T6t3J': {'danceability': 0.575,
#   'energy': 0.902,
#   'key': 2,
#   'loudness': -5.513,
#   'mode': 1,
#   'speechiness': 0.0341,
#   'acousticness': 0.13,
#   'instrumentalness': 0.0467,
#   'liveness': 0.847,
#   'valence': 0.717,
#   'tempo': 100.995,
#   'type': 'audio_features',
#   'id': '0MsMDREQOOfu9rJz8T6t3J',
#   'uri': 'spotify:track:0MsMDREQOOfu9rJz8T6t3J',
#   'track_href': 'https://api.spotify.com/v1/tracks/0MsMDREQOOfu9rJz8T6t3J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MsMDREQOOfu9rJz8T6t3J',
#   'duration_ms': 239493,
#   'time_signature': 4},
#  '5xQ7CgmLSs1z8ULyiGjx06': {'danceability': 0.523,
#   'energy': 0.901,
#   'key': 4,
#   'loudness': -5.988,
#   'mode': 0,
#   'speechiness': 0.0438,
#   'acousticness': 0.0457,
#   'instrumentalness': 1.61e-05,
#   'liveness': 0.922,
#   'valence': 0.311,
#   'tempo': 90.058,
#   'type': 'audio_features',
#   'id': '5xQ7CgmLSs1z8ULyiGjx06',
#   'uri': 'spotify:track:5xQ7CgmLSs1z8ULyiGjx06',
#   'track_href': 'https://api.spotify.com/v1/tracks/5xQ7CgmLSs1z8ULyiGjx06',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5xQ7CgmLSs1z8ULyiGjx06',
#   'duration_ms': 241987,
#   'time_signature': 4},
#  '0ruw7LB7zpO1pmYD36bvIX': {'danceability': 0.485,
#   'energy': 0.976,
#   'key': 7,
#   'loudness': -3.837,
#   'mode': 0,
#   'speechiness': 0.103,
#   'acousticness': 0.042,
#   'instrumentalness': 0.114,
#   'liveness': 0.938,
#   'valence': 0.494,
#   'tempo': 138.071,
#   'type': 'audio_features',
#   'id': '0ruw7LB7zpO1pmYD36bvIX',
#   'uri': 'spotify:track:0ruw7LB7zpO1pmYD36bvIX',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ruw7LB7zpO1pmYD36bvIX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ruw7LB7zpO1pmYD36bvIX',
#   'duration_ms': 251080,
#   'time_signature': 4},
#  '3PRp7OwnzTS5rrcodRCMxh': {'danceability': 0.364,
#   'energy': 0.981,
#   'key': 9,
#   'loudness': -5.668,
#   'mode': 1,
#   'speechiness': 0.188,
#   'acousticness': 0.0205,
#   'instrumentalness': 0.04,
#   'liveness': 0.23,
#   'valence': 0.114,
#   'tempo': 142.923,
#   'type': 'audio_features',
#   'id': '3PRp7OwnzTS5rrcodRCMxh',
#   'uri': 'spotify:track:3PRp7OwnzTS5rrcodRCMxh',
#   'track_href': 'https://api.spotify.com/v1/tracks/3PRp7OwnzTS5rrcodRCMxh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3PRp7OwnzTS5rrcodRCMxh',
#   'duration_ms': 264760,
#   'time_signature': 4},
#  '5xEV5Jbdm5uPH9xWqoDyaj': {'danceability': 0.515,
#   'energy': 0.933,
#   'key': 9,
#   'loudness': -5.37,
#   'mode': 1,
#   'speechiness': 0.0698,
#   'acousticness': 0.0126,
#   'instrumentalness': 0.0128,
#   'liveness': 0.982,
#   'valence': 0.59,
#   'tempo': 87.962,
#   'type': 'audio_features',
#   'id': '5xEV5Jbdm5uPH9xWqoDyaj',
#   'uri': 'spotify:track:5xEV5Jbdm5uPH9xWqoDyaj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5xEV5Jbdm5uPH9xWqoDyaj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5xEV5Jbdm5uPH9xWqoDyaj',
#   'duration_ms': 252267,
#   'time_signature': 4},
#  '3qdURsmC1DASAMwQQnrZkz': {'danceability': 0.423,
#   'energy': 0.959,
#   'key': 2,
#   'loudness': -6.389,
#   'mode': 1,
#   'speechiness': 0.0992,
#   'acousticness': 0.0137,
#   'instrumentalness': 0.202,
#   'liveness': 0.975,
#   'valence': 0.309,
#   'tempo': 141.913,
#   'type': 'audio_features',
#   'id': '3qdURsmC1DASAMwQQnrZkz',
#   'uri': 'spotify:track:3qdURsmC1DASAMwQQnrZkz',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qdURsmC1DASAMwQQnrZkz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qdURsmC1DASAMwQQnrZkz',
#   'duration_ms': 322973,
#   'time_signature': 4},
#  '4wNyVmbhNOL8f3GRfTpMYF': {'danceability': 0.481,
#   'energy': 0.753,
#   'key': 7,
#   'loudness': -6.476,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.231,
#   'instrumentalness': 0.000647,
#   'liveness': 0.733,
#   'valence': 0.235,
#   'tempo': 129.097,
#   'type': 'audio_features',
#   'id': '4wNyVmbhNOL8f3GRfTpMYF',
#   'uri': 'spotify:track:4wNyVmbhNOL8f3GRfTpMYF',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wNyVmbhNOL8f3GRfTpMYF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wNyVmbhNOL8f3GRfTpMYF',
#   'duration_ms': 247413,
#   'time_signature': 4},
#  '5x1u9tUaobZziKexML1b0B': {'danceability': 0.674,
#   'energy': 0.944,
#   'key': 11,
#   'loudness': -4.949,
#   'mode': 1,
#   'speechiness': 0.053,
#   'acousticness': 0.342,
#   'instrumentalness': 0,
#   'liveness': 0.919,
#   'valence': 0.805,
#   'tempo': 98.014,
#   'type': 'audio_features',
#   'id': '5x1u9tUaobZziKexML1b0B',
#   'uri': 'spotify:track:5x1u9tUaobZziKexML1b0B',
#   'track_href': 'https://api.spotify.com/v1/tracks/5x1u9tUaobZziKexML1b0B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5x1u9tUaobZziKexML1b0B',
#   'duration_ms': 334867,
#   'time_signature': 4},
#  '4JawVsHcPqzsaXlVj5Rm7e': {'danceability': 0.575,
#   'energy': 0.956,
#   'key': 11,
#   'loudness': -5.417,
#   'mode': 1,
#   'speechiness': 0.0896,
#   'acousticness': 0.166,
#   'instrumentalness': 0.122,
#   'liveness': 0.942,
#   'valence': 0.655,
#   'tempo': 137.967,
#   'type': 'audio_features',
#   'id': '4JawVsHcPqzsaXlVj5Rm7e',
#   'uri': 'spotify:track:4JawVsHcPqzsaXlVj5Rm7e',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JawVsHcPqzsaXlVj5Rm7e',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JawVsHcPqzsaXlVj5Rm7e',
#   'duration_ms': 173027,
#   'time_signature': 4},
#  '6wp1Zu6UkS1ETRB9fXtGoK': {'danceability': 0.521,
#   'energy': 0.936,
#   'key': 6,
#   'loudness': -5.228,
#   'mode': 1,
#   'speechiness': 0.0445,
#   'acousticness': 0.0163,
#   'instrumentalness': 0.0133,
#   'liveness': 0.419,
#   'valence': 0.516,
#   'tempo': 99.999,
#   'type': 'audio_features',
#   'id': '6wp1Zu6UkS1ETRB9fXtGoK',
#   'uri': 'spotify:track:6wp1Zu6UkS1ETRB9fXtGoK',
#   'track_href': 'https://api.spotify.com/v1/tracks/6wp1Zu6UkS1ETRB9fXtGoK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wp1Zu6UkS1ETRB9fXtGoK',
#   'duration_ms': 213533,
#   'time_signature': 4},
#  '6Z7I47IUGyb1XawH1jmFmN': {'danceability': 0.508,
#   'energy': 0.677,
#   'key': 7,
#   'loudness': -6.597,
#   'mode': 1,
#   'speechiness': 0.0301,
#   'acousticness': 0.498,
#   'instrumentalness': 0.00961,
#   'liveness': 0.886,
#   'valence': 0.188,
#   'tempo': 130.066,
#   'type': 'audio_features',
#   'id': '6Z7I47IUGyb1XawH1jmFmN',
#   'uri': 'spotify:track:6Z7I47IUGyb1XawH1jmFmN',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Z7I47IUGyb1XawH1jmFmN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Z7I47IUGyb1XawH1jmFmN',
#   'duration_ms': 224227,
#   'time_signature': 4},
#  '5lVl0sY3UU0l9Udakuf0Xv': {'danceability': 0.35,
#   'energy': 0.967,
#   'key': 0,
#   'loudness': -5.496,
#   'mode': 1,
#   'speechiness': 0.174,
#   'acousticness': 0.0956,
#   'instrumentalness': 0.369,
#   'liveness': 0.807,
#   'valence': 0.314,
#   'tempo': 141.131,
#   'type': 'audio_features',
#   'id': '5lVl0sY3UU0l9Udakuf0Xv',
#   'uri': 'spotify:track:5lVl0sY3UU0l9Udakuf0Xv',
#   'track_href': 'https://api.spotify.com/v1/tracks/5lVl0sY3UU0l9Udakuf0Xv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5lVl0sY3UU0l9Udakuf0Xv',
#   'duration_ms': 217760,
#   'time_signature': 4},
#  '3FxWsh6NNLUgdHbtsFCXTg': {'danceability': 0.499,
#   'energy': 0.913,
#   'key': 7,
#   'loudness': -5.665,
#   'mode': 1,
#   'speechiness': 0.0487,
#   'acousticness': 0.0665,
#   'instrumentalness': 7.13e-06,
#   'liveness': 0.947,
#   'valence': 0.625,
#   'tempo': 138.084,
#   'type': 'audio_features',
#   'id': '3FxWsh6NNLUgdHbtsFCXTg',
#   'uri': 'spotify:track:3FxWsh6NNLUgdHbtsFCXTg',
#   'track_href': 'https://api.spotify.com/v1/tracks/3FxWsh6NNLUgdHbtsFCXTg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3FxWsh6NNLUgdHbtsFCXTg',
#   'duration_ms': 224893,
#   'time_signature': 4},
#  '6nLtC1GWYE8FPhhZDYmj5d': {'danceability': 0.487,
#   'energy': 0.918,
#   'key': 0,
#   'loudness': -5.202,
#   'mode': 1,
#   'speechiness': 0.0624,
#   'acousticness': 0.0596,
#   'instrumentalness': 2.31e-05,
#   'liveness': 0.937,
#   'valence': 0.52,
#   'tempo': 147.984,
#   'type': 'audio_features',
#   'id': '6nLtC1GWYE8FPhhZDYmj5d',
#   'uri': 'spotify:track:6nLtC1GWYE8FPhhZDYmj5d',
#   'track_href': 'https://api.spotify.com/v1/tracks/6nLtC1GWYE8FPhhZDYmj5d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nLtC1GWYE8FPhhZDYmj5d',
#   'duration_ms': 215107,
#   'time_signature': 4},
#  '2ciyvQ4LNxlquE8ch5Nnd5': {'danceability': 0.514,
#   'energy': 0.938,
#   'key': 4,
#   'loudness': -5.098,
#   'mode': 1,
#   'speechiness': 0.0604,
#   'acousticness': 0.0227,
#   'instrumentalness': 5.43e-05,
#   'liveness': 0.929,
#   'valence': 0.429,
#   'tempo': 116.063,
#   'type': 'audio_features',
#   'id': '2ciyvQ4LNxlquE8ch5Nnd5',
#   'uri': 'spotify:track:2ciyvQ4LNxlquE8ch5Nnd5',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ciyvQ4LNxlquE8ch5Nnd5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ciyvQ4LNxlquE8ch5Nnd5',
#   'duration_ms': 215547,
#   'time_signature': 4},
#  '4w3cSH5WO9US8M6JslxtQI': {'danceability': 0.507,
#   'energy': 0.721,
#   'key': 9,
#   'loudness': -7.922,
#   'mode': 1,
#   'speechiness': 0.0453,
#   'acousticness': 0.852,
#   'instrumentalness': 4.71e-05,
#   'liveness': 0.903,
#   'valence': 0.484,
#   'tempo': 96.061,
#   'type': 'audio_features',
#   'id': '4w3cSH5WO9US8M6JslxtQI',
#   'uri': 'spotify:track:4w3cSH5WO9US8M6JslxtQI',
#   'track_href': 'https://api.spotify.com/v1/tracks/4w3cSH5WO9US8M6JslxtQI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4w3cSH5WO9US8M6JslxtQI',
#   'duration_ms': 190387,
#   'time_signature': 4},
#  '6op963izlXngtlIgYHEV2o': {'danceability': 0.357,
#   'energy': 0.837,
#   'key': 7,
#   'loudness': -5.841,
#   'mode': 1,
#   'speechiness': 0.045,
#   'acousticness': 0.349,
#   'instrumentalness': 0.000698,
#   'liveness': 0.978,
#   'valence': 0.379,
#   'tempo': 152.54,
#   'type': 'audio_features',
#   'id': '6op963izlXngtlIgYHEV2o',
#   'uri': 'spotify:track:6op963izlXngtlIgYHEV2o',
#   'track_href': 'https://api.spotify.com/v1/tracks/6op963izlXngtlIgYHEV2o',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6op963izlXngtlIgYHEV2o',
#   'duration_ms': 276147,
#   'time_signature': 4},
#  '1YMJFaOnnQZTLKK1r3YmvH': {'danceability': 0.672,
#   'energy': 0.655,
#   'key': 1,
#   'loudness': -7.241,
#   'mode': 0,
#   'speechiness': 0.0514,
#   'acousticness': 0.185,
#   'instrumentalness': 1.43e-05,
#   'liveness': 0.718,
#   'valence': 0.379,
#   'tempo': 119.963,
#   'type': 'audio_features',
#   'id': '1YMJFaOnnQZTLKK1r3YmvH',
#   'uri': 'spotify:track:1YMJFaOnnQZTLKK1r3YmvH',
#   'track_href': 'https://api.spotify.com/v1/tracks/1YMJFaOnnQZTLKK1r3YmvH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1YMJFaOnnQZTLKK1r3YmvH',
#   'duration_ms': 207733,
#   'time_signature': 4},
#  '63eEfkixJgqN2txqfw9naX': {'danceability': 0.528,
#   'energy': 0.709,
#   'key': 4,
#   'loudness': -7.407,
#   'mode': 1,
#   'speechiness': 0.0367,
#   'acousticness': 0.665,
#   'instrumentalness': 3.13e-06,
#   'liveness': 0.764,
#   'valence': 0.379,
#   'tempo': 79.966,
#   'type': 'audio_features',
#   'id': '63eEfkixJgqN2txqfw9naX',
#   'uri': 'spotify:track:63eEfkixJgqN2txqfw9naX',
#   'track_href': 'https://api.spotify.com/v1/tracks/63eEfkixJgqN2txqfw9naX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63eEfkixJgqN2txqfw9naX',
#   'duration_ms': 386723,
#   'time_signature': 4},
#  '5JBAs56Oj2W8tRoOrntKwm': {'danceability': 0.482,
#   'energy': 0.455,
#   'key': 9,
#   'loudness': -9.51,
#   'mode': 1,
#   'speechiness': 0.0273,
#   'acousticness': 0.225,
#   'instrumentalness': 0.0432,
#   'liveness': 0.357,
#   'valence': 0.221,
#   'tempo': 76.037,
#   'type': 'audio_features',
#   'id': '5JBAs56Oj2W8tRoOrntKwm',
#   'uri': 'spotify:track:5JBAs56Oj2W8tRoOrntKwm',
#   'track_href': 'https://api.spotify.com/v1/tracks/5JBAs56Oj2W8tRoOrntKwm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5JBAs56Oj2W8tRoOrntKwm',
#   'duration_ms': 253840,
#   'time_signature': 4},
#  '4a3twTGIFwHZLkaSMDMdOo': {'danceability': 0.541,
#   'energy': 0.695,
#   'key': 9,
#   'loudness': -6.633,
#   'mode': 1,
#   'speechiness': 0.0301,
#   'acousticness': 0.655,
#   'instrumentalness': 0.000228,
#   'liveness': 0.937,
#   'valence': 0.469,
#   'tempo': 80.189,
#   'type': 'audio_features',
#   'id': '4a3twTGIFwHZLkaSMDMdOo',
#   'uri': 'spotify:track:4a3twTGIFwHZLkaSMDMdOo',
#   'track_href': 'https://api.spotify.com/v1/tracks/4a3twTGIFwHZLkaSMDMdOo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4a3twTGIFwHZLkaSMDMdOo',
#   'duration_ms': 205480,
#   'time_signature': 4},
#  '1CgaSnzUIbLvu0El4vYdBu': {'danceability': 0.539,
#   'energy': 0.83,
#   'key': 9,
#   'loudness': -6.84,
#   'mode': 1,
#   'speechiness': 0.0417,
#   'acousticness': 0.0122,
#   'instrumentalness': 4.9e-06,
#   'liveness': 0.723,
#   'valence': 0.408,
#   'tempo': 142.148,
#   'type': 'audio_features',
#   'id': '1CgaSnzUIbLvu0El4vYdBu',
#   'uri': 'spotify:track:1CgaSnzUIbLvu0El4vYdBu',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CgaSnzUIbLvu0El4vYdBu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CgaSnzUIbLvu0El4vYdBu',
#   'duration_ms': 471451,
#   'time_signature': 4},
#  '0WAyILl76rFQMaAfbk8Cc0': {'danceability': 0.383,
#   'energy': 0.647,
#   'key': 11,
#   'loudness': -8.144,
#   'mode': 0,
#   'speechiness': 0.0388,
#   'acousticness': 0.0122,
#   'instrumentalness': 0.000286,
#   'liveness': 0.765,
#   'valence': 0.13,
#   'tempo': 77.931,
#   'type': 'audio_features',
#   'id': '0WAyILl76rFQMaAfbk8Cc0',
#   'uri': 'spotify:track:0WAyILl76rFQMaAfbk8Cc0',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WAyILl76rFQMaAfbk8Cc0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WAyILl76rFQMaAfbk8Cc0',
#   'duration_ms': 373878,
#   'time_signature': 4}}
# [Stage 266:>                                                        (0 + 1) / 1]

# %%
# Adicionamos os atributos de áudio ao dataframe
df_tracks['acousticness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['acousticness'])
df_tracks['speechiness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['speechiness'])
df_tracks['key'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['key'])
df_tracks['liveness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['liveness'])
df_tracks['instrumentalness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['instrumentalness'])
df_tracks['energy'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['energy'])
df_tracks['tempo'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['tempo'])
df_tracks['loudness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['loudness'])
df_tracks['danceability'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['danceability'])
df_tracks['valence'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['valence'])

# %%
df_tracks.head()
# Out:
#                        id                           name      artists  \
# 0  4zgyHc0bK2ca1U9X2iajg3  A Força do Silêncio (Ao Vivo)  Pouca Vogal
# 1  3OtbktRUMTzYrGTrdKaJUn           A Montanha (Ao Vivo)  Pouca Vogal
# 2  6RWbbxUbtbadvUtg4tz1ab     O Vôo do Besouro (Ao Vivo)  Pouca Vogal
# 3  5eMgoUmfSjCdiUaP0fNgDD          Pouca Vogal (Ao Vivo)  Pouca Vogal
# 4  7rL1ExqyusHQJjXZ2ZSDxQ    O Amanhã Colorido (Ao Vivo)  Pouca Vogal
#
#    popularity  acousticness  speechiness  key  liveness  instrumentalness  \
# 0          31         0.624       0.0311    2     0.737           0.00000
# 1          29         0.882       0.0286    7     0.726           0.00966
# 2          26         0.823       0.0306    4     0.969           0.00005
# 3          24         0.719       0.0462    9     0.979           0.03120
# 4          37         0.188       0.0366    2     0.983           0.00000
#
#    energy    tempo  loudness  danceability  valence
# 0   0.618  138.010    -7.509         0.550    0.684
# 1   0.366  137.822   -12.399         0.556    0.460
# 2   0.357  132.033   -12.167         0.599    0.224
# 3   0.633  103.239    -8.023         0.381    0.350
# 4   0.609  122.056    -7.791         0.505    0.572

# %%
# Selecionamos uma música randomicamente do nosso dataframe
musica_randomica = random.randint(0,len(df_tracks)-1)
df_musica_randomica = df_tracks.head(musica_randomica)[-1:]
df_musica_randomica
# Out:
#                         id                name     artists  popularity  \
# 20  3g5FrnRdbmDQyWNiDIprts  All Star - Ao Vivo  Nando Reis          63
#
#     acousticness  speechiness  key  liveness  instrumentalness  energy  \
# 20         0.889       0.0492    9     0.714          0.000003   0.391
#
#       tempo  loudness  danceability  valence
# 20  138.094     -10.4         0.512    0.277

# %%
# Músicas do straming do Spark
# Do streaming que ta vindo do kafka
spark_songs.show(5)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+
# |                  id|                name|popularity|             artists|danceability|energy| key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|tempo|
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+
# |5pOumPAUcd7bgJi47...|       Nobody's Ting|         4|                NDAI|       0.525|   2.0|null|     1.0|      0.388|         0.0|           0.099|   0.528|143.912|  4.0|
# |4YY8nv8tzU7AKLyRx...|                 You|         4|         GylesBartle|       0.331|   0.0|null|     1.0|      0.268|       0.327|           0.363|   0.663| 72.083|  4.0|
# |7fAJw7CNYOOMbYr3S...|           Amor Fati|         0|ChampagneSuperchi...|       0.841|   2.0|null|     0.0|      0.123|       0.118|           0.117|   0.689|118.334|  4.0|
# |4SzpxKCWRcKNNce1J...|Georgie Wants a G...|         9|            Blackaby|       0.573|  11.0|null|     1.0|      0.819|      0.0556|           0.118|   0.823|113.054|  4.0|
# |40Ub2OAfCIxJa7OaO...|           So Simple|         6|      LucyandtheRats|       0.881|   4.0|null|     1.0|    0.00628|     1.64E-4|          0.0887|   0.444|151.737|  4.0|
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+
# only showing top 5 rows

# %%
# Ainda na lista de músicas que está vindo do kafka vou excluir algumas colunas que não precisaremos
spark_songs = spark_songs.drop('order_id',
                               'mode',
                               'release_date',
                               'id_artists',
                               'time_signature',
                               'duration_ms',
                               'timestamp')

# %%
# Cria o dataframe com a música escolhida randomicamente
df_sp = spark.createDataFrame(df_musica_randomica)

# %%
# Concatena músicas do streaming do Spark com a música do Spotify
df = spark_songs.union(df_sp)

# %%
df.show(5)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+
# |                  id|                name|popularity|             artists|danceability|energy| key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|tempo|
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+
# |5pOumPAUcd7bgJi47...|       Nobody's Ting|         4|                NDAI|       0.525|   2.0|null|     1.0|      0.388|         0.0|           0.099|   0.528|143.912|  4.0|
# |4YY8nv8tzU7AKLyRx...|                 You|         4|         GylesBartle|       0.331|   0.0|null|     1.0|      0.268|       0.327|           0.363|   0.663| 72.083|  4.0|
# |7fAJw7CNYOOMbYr3S...|           Amor Fati|         0|ChampagneSuperchi...|       0.841|   2.0|null|     0.0|      0.123|       0.118|           0.117|   0.689|118.334|  4.0|
# |4SzpxKCWRcKNNce1J...|Georgie Wants a G...|         9|            Blackaby|       0.573|  11.0|null|     1.0|      0.819|      0.0556|           0.118|   0.823|113.054|  4.0|
# |40Ub2OAfCIxJa7OaO...|           So Simple|         6|      LucyandtheRats|       0.881|   4.0|null|     1.0|    0.00628|     1.64E-4|          0.0887|   0.444|151.737|  4.0|
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+
# only showing top 5 rows

# %% [markdown]
# ### Pré-Processamento dos Dados

# %%
# Preparamos o VectorAssembler
vetor = VectorAssembler(inputCols = ['danceability',
                                     'energy',
                                     'loudness',
                                     'speechiness',
                                     'acousticness',
                                     'instrumentalness',
                                     'liveness',
                                     'valence',
                                     'tempo'],
                       outputCol = 'song_features')

# %%
# Descartamos valores inválidos
assembled = vetor.setHandleInvalid('skip').transform(df)

# %%
# Preparamos o padronizador
std = StandardScaler(inputCol = 'song_features', outputCol = 'standardized')

# %%
# Treinamos o padronizador
scale = std.fit(assembled)

# %%
# Dataframe com dados padronizados
df = scale.transform(assembled)

# %%
df.show(5)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+--------------------+--------------------+
# |                  id|                name|popularity|             artists|danceability|energy| key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|tempo|       song_features|        standardized|
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+--------------------+--------------------+
# |5pOumPAUcd7bgJi47...|       Nobody's Ting|         4|                NDAI|       0.525|   2.0|null|     1.0|      0.388|         0.0|           0.099|   0.528|143.912|  4.0|[0.525,2.0,1.0,0....|[2.64468078997192...|
# |4YY8nv8tzU7AKLyRx...|                 You|         4|         GylesBartle|       0.331|   0.0|null|     1.0|      0.268|       0.327|           0.363|   0.663| 72.083|  4.0|[0.331,0.0,1.0,0....|[1.66740826948706...|
# |7fAJw7CNYOOMbYr3S...|           Amor Fati|         0|ChampagneSuperchi...|       0.841|   2.0|null|     0.0|      0.123|       0.118|           0.117|   0.689|118.334|  4.0|[0.841,2.0,0.0,0....|[4.23652675117407...|
# |4SzpxKCWRcKNNce1J...|Georgie Wants a G...|         9|            Blackaby|       0.573|  11.0|null|     1.0|      0.819|      0.0556|           0.118|   0.823|113.054|  4.0|[0.573,11.0,1.0,0...|[2.88648017648364...|
# |40Ub2OAfCIxJa7OaO...|           So Simple|         6|      LucyandtheRats|       0.881|   4.0|null|     1.0|    0.00628|     1.64E-4|          0.0887|   0.444|151.737|  4.0|[0.881,4.0,1.0,0....|[4.43802623993384...|
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ### Machine Learning com Aprendizado Não Supervisionado

# %%
# Cria o objeto do modelo
objeto_KMeans = KMeans(featuresCol = 'standardized', k = 3)

# %%
# Treina o modelo
modelo_KMeans = objeto_KMeans.fit(df)

# %%
# Previsões do modelo
df_output = modelo_KMeans.transform(df)

# %%
df_output.show(10)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+--------------------+--------------------+----------+
# |                  id|                name|popularity|             artists|danceability|energy| key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|tempo|       song_features|        standardized|prediction|
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+--------------------+--------------------+----------+
# |5pOumPAUcd7bgJi47...|       Nobody's Ting|         4|                NDAI|       0.525|   2.0|null|     1.0|      0.388|         0.0|           0.099|   0.528|143.912|  4.0|[0.525,2.0,1.0,0....|[2.64468078997192...|         0|
# |4YY8nv8tzU7AKLyRx...|                 You|         4|         GylesBartle|       0.331|   0.0|null|     1.0|      0.268|       0.327|           0.363|   0.663| 72.083|  4.0|[0.331,0.0,1.0,0....|[1.66740826948706...|         0|
# |7fAJw7CNYOOMbYr3S...|           Amor Fati|         0|ChampagneSuperchi...|       0.841|   2.0|null|     0.0|      0.123|       0.118|           0.117|   0.689|118.334|  4.0|[0.841,2.0,0.0,0....|[4.23652675117407...|         0|
# |4SzpxKCWRcKNNce1J...|Georgie Wants a G...|         9|            Blackaby|       0.573|  11.0|null|     1.0|      0.819|      0.0556|           0.118|   0.823|113.054|  4.0|[0.573,11.0,1.0,0...|[2.88648017648364...|         0|
# |40Ub2OAfCIxJa7OaO...|           So Simple|         6|      LucyandtheRats|       0.881|   4.0|null|     1.0|    0.00628|     1.64E-4|          0.0887|   0.444|151.737|  4.0|[0.881,4.0,1.0,0....|[4.43802623993384...|         0|
# |2RnTn9CS7jb6TcDjL...|             reasons|        19|          wishedbone|       0.366|   3.0|null|     1.0|      0.848|       0.802|           0.107|   0.283|111.772|  4.0|[0.366,3.0,1.0,0....|[1.84372032215185...|         2|
# |6WhXE4p7k0Hn0TsAG...|             Baptist|         1|               Lucas|        0.43|   6.0|null|     0.0|      0.397|        0.05|          0.0817|  0.0534| 82.154|  4.0|[0.43,6.0,0.0,0.3...|[2.16611950416748...|         0|
# |7EcAPjzJJGzT0v5Ly...| Shadows Show Violet|        13|    CroatianAmorVarg|       0.508|   8.0|null|     1.0|      0.142|       0.906|           0.354|  0.0412|128.096|  4.0|[0.508,8.0,1.0,0....|[2.55904350724902...|         2|
# |5JL0tR8jwaCa5PCrd...|               Void.|         5|             shibuya|       0.853|   1.0|null|     1.0|     0.0016|       0.812|           0.401|   0.198|  133.8|  4.0|[0.853,1.0,1.0,0....|[4.29697659780200...|         2|
# |6QU2TvoFcY4qnpqM4...|   Last Day on Earth|         2|     PacificPatterns|       0.931|  10.0|null|     0.0|     0.0934|        0.16|           0.152|    0.24| 83.586|  4.0|[0.931,10.0,0.0,0...|[4.68990060088355...|         0|
# +--------------------+--------------------+----------+--------------------+------------+------+----+--------+-----------+------------+----------------+--------+-------+-----+--------------------+--------------------+----------+
# only showing top 10 rows

# %% [markdown]
# ### Sistema de Recomendação

# %%
# Classe
class RecoSystem():
    
    # Método construtor
    def __init__(self, data):
        self.data_ = data
    
    # Método de recomendação
    def Recomm(self, nome_musica, amount = 1):
        
        # Lista para as distâncias
        distancias = []
        
        # Seleciona a música
        song = self.data_[(self.data_.name.str.lower() == nome_musica.lower())].head(1).values[0]
        res_dt = self.data_[self.data_.name.str.lower() != nome_musica.lower()]
        
        # Loop para o cálculo das distâncias
        for i_song in tqdm(res_dt.values):
            
            # Inicializa a distância
            distancia = 0
            
            # Loop para calcular a distância
            for col in np.arange(len(res_dt.columns)):
                if not col in [0,1,2,14]:
                    distancia = distancia + np.absolute(float(song[col]) - float(i_song[col]))
            
            # Adiciona na lista de distâncias
            distancias.append(distancia)
        
        res_dt['distance'] = distancias
        res_dt = res_dt.sort_values('distance')
        
        columns = ['id','name', 
                   'artists', 
                   'acousticness', 
                   'liveness', 
                   'instrumentalness', 
                   'energy', 
                   'danceability', 
                   'valence']
        
        return res_dt[columns][:amount]

# %%
# Selecionando as colunas do nosso dataframe de previsões
datalabel = df_output.select('id',
                             'name',
                             'artists',
                             'danceability',
                             'energy',
                             'key',
                             'loudness',
                             'speechiness',
                             'acousticness',
                             'instrumentalness',
                             'liveness',
                             'valence',
                             'tempo',
                             'prediction')

# %%
# Dataset final
df_final = datalabel.toPandas()
df_final.drop(df_final[df_final['artists'] == '0'].index, inplace = True)
df_final.drop_duplicates(inplace = True)
df_final.drop(df_final[df_final['danceability'] == 0.0000].index, inplace = True)
df_final.drop(df_final[df_final['liveness'] == 0.000].index, inplace = True)
df_final.drop(df_final[df_final['instrumentalness'] == 0.000000].index, inplace = True)
df_final.drop(df_final[df_final['energy'] == 0.0000].index, inplace = True)
df_final.drop(df_final[df_final['danceability'] == 0.000].index, inplace = True)
df_final.drop(df_final[df_final['valence'] == 0.000].index, inplace = True)

# %%
df_final.shape
# Out:
# (2346, 14)

# %%
df_final.sample(5)
# Out:
#                           id            name     artists  danceability  \
# 141   6mAOLBah2eqPYDrCu16AOG           Bratt       HALEY         0.724
# 1545  27x8TJNYboxPv6KheHY1AS     Easy Enough   LeTrouble         0.502
# 1521  6mY56gQjKYzpwyK2PNRJst       One Chick      Sondai         0.633
# 999   6YPzUKk6TQPkwZAxrxCxge  Feel Something       Sgrow         0.680
# 504   6xrwKRPvVAKBLF365OA8MV      Retrograde  QNABushTea         0.656
#
#       energy  key  loudness  speechiness  acousticness  instrumentalness  \
# 141      1.0  NaN       0.0       0.0479      0.029500            0.2740
# 1545     5.0  NaN       1.0       0.5930      0.577000            0.0975
# 1521     9.0  NaN       0.0       0.3060      0.000000            0.3530
# 999      6.0  NaN       1.0       0.0849      0.236000            0.1170
# 504     10.0  NaN       0.0       0.3310      0.000011            0.1040
#
#       liveness  valence  tempo  prediction
# 141      0.095  128.003    4.0           0
# 1545     0.483  132.813    4.0           2
# 1521     0.932  136.086    4.0           0
# 999      0.487   97.732    4.0           0
# 504      0.306  167.700    4.0           0

# %%
# Cria o objeto 
reco_obj = RecoSystem(df_final)

# %%
musica = df_musica_randomica['name'].tolist()[0]

# %%
print(musica)
# Out:
# All Star - Ao Vivo

# %%
# Executa a recomendação
recomendacao = reco_obj.Recomm(musica)
# Out:
# 100%|████████████████████████████████████| 2345/2345 [00:00<00:00, 42969.17it/s]

# %%
# Extrai a música randômica da lista de favoritos do Spotify:
y = df_musica_randomica[['id', 'name',
                         'artists',
                         'acousticness',
                         'liveness',
                         'instrumentalness',
                         'energy',
                         'danceability',
                         'valence']]

# %%
# Concatena a recomendação com a música randômica da lista de favoritos do Spotify
recomendacao = pd.concat([recomendacao, y])

# %%
# Salva a recomendação em disco
recomendacao.to_csv('recomendacao.csv')

# %%
# Carrega o arquivo do disco
df_reco = (spark.read.format('csv').options(header = 'true').load('recomendacao.csv'))

# %%
# Recomendação de música
df_reco.show()
# Out:
# +---+--------------------+--------------------+----------+------------+--------+----------------+------+------------+-------+
# |_c0|                  id|                name|   artists|acousticness|liveness|instrumentalness|energy|danceability|valence|
# +---+--------------------+--------------------+----------+------------+--------+----------------+------+------------+-------+
# |320|4TwFQpzVR47KLXwej...|Portal (feat. Riz...|    252501|       0.887|   0.187|           0.688| 0.291|       0.323|  0.124|
# | 20|3g5FrnRdbmDQyWNiD...|  All Star - Ao Vivo|Nando Reis|       0.889|   0.714|        2.63e-06| 0.391|       0.512|  0.277|
# +---+--------------------+--------------------+----------+------------+--------+----------------+------+------------+-------+
