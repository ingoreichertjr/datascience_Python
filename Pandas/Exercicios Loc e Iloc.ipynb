# %%
import pandas as pd

# %%
df = pd.read_csv('http://sistema.cenipa.aer.mil.br/cenipa/media/opendata/ocorrencia.csv', sep=";", index_col='codigo_ocorrencia')

# %%
df
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 80898                           80898               80898               80898
# 80895                           80895               80895               80895
# 80894                           80894               80894               80894
# 80887                           80887               80887               80887
# 80886                           80886               80886               80886
# ...                               ...                 ...                 ...
# 45333                           45333               45333               45333
# 45401                           45401               45401               45401
# 45407                           45407               45407               45407
# 52243                           52243               52243               52243
# 52242                           52242               52242               52242
#
# ...

# %%
df = df.drop(['codigo_ocorrencia1', 'codigo_ocorrencia2', 'codigo_ocorrencia3', 'codigo_ocorrencia4'], axis = 1)

# %%
df.head()
# Out:
#                   ocorrencia_classificacao ocorrencia_latitude  \
# codigo_ocorrencia
# 80898                      INCIDENTE GRAVE          -23.330278
# 80895                      INCIDENTE GRAVE     -16.70611111111
# 80894                            INCIDENTE          -15.438611
# 80887                            INCIDENTE          -22.810000
# 80886                            INCIDENTE            -7.27888
#
#                   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# codigo_ocorrencia
# 80898                       -51.136667          LONDRINA            PR
# 80895                  -43.82194444444     MONTES CLAROS            MG
# 80894                       -51.598333           JUSSARA            GO
# 80887                       -43.250556    RIO DE JANEIRO            RJ
# 80886                        -64.76944            LÁBREA            AM
#
#                   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia  \
# codigo_ocorrencia
# ...

# %%
# Para o loc usarei estes indices
df.index
# Out:
# Int64Index([80898, 80895, 80894, 80887, 80886, 80891, 80896, 80882, 80883,
#             80884,
#             ...
#             45334, 45391, 52244, 50713, 45331, 45333, 45401, 45407, 52243,
#             52242],
#            dtype='int64', name='codigo_ocorrencia', length=5529)

# %%
df.loc[80882]
# Out:
# ocorrencia_classificacao           INCIDENTE
# ocorrencia_latitude                 -22.3436
# ocorrencia_longitude                -49.0538
# ocorrencia_cidade                      BAURU
# ocorrencia_uf                             SP
# ocorrencia_pais                       BRASIL
# ocorrencia_aerodromo                    SBBU
# ocorrencia_dia                    27/07/2022
# ocorrencia_hora                     17:30:00
# investigacao_aeronave_liberada           SIM
# investigacao_status               FINALIZADA
# divulgacao_relatorio_numero              ***
# divulgacao_relatorio_publicado           NÃO
# divulgacao_dia_publicacao                NaN
# total_recomendacoes                        0
# total_aeronaves_envolvidas                 2
# ocorrencia_saida_pista                   NÃO
# Name: 80882, dtype: object

# %%
df.iloc[7]
# Out:
# ocorrencia_classificacao           INCIDENTE
# ocorrencia_latitude                 -22.3436
# ocorrencia_longitude                -49.0538
# ocorrencia_cidade                      BAURU
# ocorrencia_uf                             SP
# ocorrencia_pais                       BRASIL
# ocorrencia_aerodromo                    SBBU
# ocorrencia_dia                    27/07/2022
# ocorrencia_hora                     17:30:00
# investigacao_aeronave_liberada           SIM
# investigacao_status               FINALIZADA
# divulgacao_relatorio_numero              ***
# divulgacao_relatorio_publicado           NÃO
# divulgacao_dia_publicacao                NaN
# total_recomendacoes                        0
# total_aeronaves_envolvidas                 2
# ocorrencia_saida_pista                   NÃO
# Name: 80882, dtype: object

# %%
df.loc[df['ocorrencia_classificacao'] == 'ACIDENTE', :]
# Out:
#                   ocorrencia_classificacao ocorrencia_latitude  \
# codigo_ocorrencia
# 80885                             ACIDENTE           -14,92416
# 80879                             ACIDENTE          -21.065556
# 80871                             ACIDENTE           -22,95941
# 80858                             ACIDENTE            2.440402
# 80856                             ACIDENTE          - 2.728333
# ...                                    ...                 ...
# 45391                             ACIDENTE      -19.9133333333
# 45331                             ACIDENTE      -23.4355555556
# 45333                             ACIDENTE                 ***
# 45401                             ACIDENTE                 ***
# 45407                             ACIDENTE                 ***
#
#                   ocorrencia_longitude      ocorrencia_cidade ocorrencia_uf  \
# codigo_ocorrencia
# 80885                        -41,95666               CONDEÚBA            BA
# ...

# %%
df.loc[df['ocorrencia_classificacao'] == 'ACIDENTE', ['ocorrencia_cidade', 'ocorrencia_hora']].shape
# Out:
# (1753, 2)

# %%
df.value_counts('ocorrencia_cidade')
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO    268
# SÃO PAULO         265
# CAMPINAS          188
# BELO HORIZONTE    175
# GUARULHOS         141
#                  ...
# ORIZONA             1
# CABREÚVA            1
# ORÓS                1
# CABEDELO            1
# COSTA RICA          1
# Length: 1090, dtype: int64

# %%
df.loc[(df['ocorrencia_classificacao'] == 'ACIDENTE') & (df['ocorrencia_uf'] == 'SP'), :]
# Out:
#                   ocorrencia_classificacao ocorrencia_latitude  \
# codigo_ocorrencia
# 80818                             ACIDENTE           -23.69803
# 80797                             ACIDENTE            -20.2766
# 80800                             ACIDENTE            -22.1019
# 80736                             ACIDENTE          -23.285703
# 80720                             ACIDENTE           -23.30942
# ...                                    ...                 ...
# 45572                             ACIDENTE      -20.3563888889
# 45410                             ACIDENTE          -23.005278
# 45408                             ACIDENTE      -24.5888888889
# 45331                             ACIDENTE      -23.4355555556
# 45401                             ACIDENTE                 ***
#
#                   ocorrencia_longitude  ocorrencia_cidade ocorrencia_uf  \
# codigo_ocorrencia
# 80818                        -47.55695  SALTO DE PIRAPORA            SP
# ...

# %%
df.loc[(df['ocorrencia_classificacao'] == 'ACIDENTE') & (df['ocorrencia_uf'].isin(['SP', 'RJ'])), :]
# Out:
#                   ocorrencia_classificacao ocorrencia_latitude  \
# codigo_ocorrencia
# 80818                             ACIDENTE           -23.69803
# 80797                             ACIDENTE            -20.2766
# 80800                             ACIDENTE            -22.1019
# 80736                             ACIDENTE          -23.285703
# 80720                             ACIDENTE           -23.30942
# ...                                    ...                 ...
# 45393                             ACIDENTE            -22.9875
# 45410                             ACIDENTE          -23.005278
# 45408                             ACIDENTE      -24.5888888889
# 45331                             ACIDENTE      -23.4355555556
# 45401                             ACIDENTE                 ***
#
#                   ocorrencia_longitude  ocorrencia_cidade ocorrencia_uf  \
# codigo_ocorrencia
# 80818                        -47.55695  SALTO DE PIRAPORA            SP
# ...

# %%
df.loc[80720]
# Out:
# ocorrencia_classificacao                   ACIDENTE
# ocorrencia_latitude                       -23.30942
# ocorrencia_longitude                      -47.70998
# ocorrencia_cidade                           BOITUVA
# ocorrencia_uf                                    SP
# ocorrencia_pais                              BRASIL
# ocorrencia_aerodromo                           ****
# ocorrencia_dia                           11/05/2022
# ocorrencia_hora                            15:05:00
# investigacao_aeronave_liberada                  SIM
# investigacao_status                           ATIVA
# divulgacao_relatorio_numero       A-063/CENIPA/2022
# divulgacao_relatorio_publicado                  NÃO
# divulgacao_dia_publicacao                       NaN
# total_recomendacoes                               0
# total_aeronaves_envolvidas                        1
# ocorrencia_saida_pista                          NÃO
# Name: 80720, dtype: object

# %%
df.loc[80720, ['ocorrencia_classificacao', 'ocorrencia_cidade']]
# Out:
# ocorrencia_classificacao    ACIDENTE
# ocorrencia_cidade            BOITUVA
# Name: 80720, dtype: object
